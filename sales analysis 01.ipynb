# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample Dataset
data = {
    "OrderID": [101,102,103,104,105,106,107,108,109,110],
    "Region": ["North","South","East","West","North","South","East","West","North","South"],
    "Product": ["Laptop","Mouse","Keyboard","Laptop","Mouse","Keyboard","Laptop","Mouse","Keyboard","Laptop"],
    "Quantity": [2,5,3,1,4,6,2,7,5,3],
    "Price": [50000,500,1500,52000,600,1400,51000,550,1600,53000]
}

df = pd.DataFrame(data)

# Total Sales Column
df["Total_Sales"] = df["Quantity"] * df["Price"]

print(df)
# Out:
#    OrderID Region   Product  Quantity  Price  Total_Sales
# 0      101  North    Laptop         2  50000       100000
# 1      102  South     Mouse         5    500         2500
# 2      103   East  Keyboard         3   1500         4500
# 3      104   West    Laptop         1  52000        52000
# 4      105  North     Mouse         4    600         2400
# 5      106  South  Keyboard         6   1400         8400
# 6      107   East    Laptop         2  51000       102000
# 7      108   West     Mouse         7    550         3850
# 8      109  North  Keyboard         5   1600         8000
# 9      110  South    Laptop         3  53000       159000

# %%
print("Mean Sales:", np.mean(df["Total_Sales"]))
print("Median Sales:", np.median(df["Total_Sales"]))
print("Standard Deviation:", np.std(df["Total_Sales"]))
print("Minimum Sales:", np.min(df["Total_Sales"]))
print("Maximum Sales:", np.max(df["Total_Sales"]))
# Out:
# Mean Sales: 44265.0
# Median Sales: 8200.0
# Standard Deviation: 53830.04760354573
# Minimum Sales: 2400
# Maximum Sales: 159000

# %%
# #calculates the correlation between the Quantity and Price columns and returns a correlation matrix.
# It measures how strongly two variables are related.

# %%
correlation = np.corrcoef(df["Quantity"], df["Price"])
print("Correlation Matrix:\n", correlation)
# Out:
# Correlation Matrix:
#  [[ 1.         -0.80158635]
#  [-0.80158635  1.        ]]

# %%
region_sales = df.groupby("Region")["Total_Sales"].sum()
print(region_sales)
# Out:
# Region
# East     106500
# North    110400
# South    169900
# West      55850
# Name: Total_Sales, dtype: int64

# %%
region_sales.plot(kind="bar")
plt.title("Region Wise Total Sales")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.savefig("region_sales.png")
plt.show()

# %%
plt.plot(df["OrderID"], df["Total_Sales"])
plt.title("Sales Trend")
plt.xlabel("OrderID")
plt.ylabel("Total Sales")
plt.savefig("sales_trend.png")
plt.show()

# %%
product_sales = df.groupby("Product")["Total_Sales"].sum()
print(product_sales)

plt.pie(product_sales,labels=product_sales.index,  autopct="%1.1f%%")
plt.title("Product Wise Sales Distribution")
plt.savefig("product_sales.png")
plt.show()
# Out:
# Product
# Keyboard     20900
# Laptop      413000
# Mouse         8750
# Name: Total_Sales, dtype: int64

# %%
plt.hist(df["Total_Sales"], bins=5)
plt.title("Sales Distribution")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.savefig("sales distribution")
plt.show()

# %%
plt.scatter(df["Quantity"], df["Price"])
plt.title("Quantity vs Price")
plt.xlabel("Quantity")
plt.ylabel("Price")
plt.savefig("quantity vs price")
plt.show()

# %%
print("25th Percentile:", np.percentile(df["Total_Sales"], 25))
print("50th Percentile:", np.percentile(df["Total_Sales"], 50))
print("75th Percentile:", np.percentile(df["Total_Sales"], 75))
# Out:
# 25th Percentile: 4012.5
# 50th Percentile: 8200.0
# 75th Percentile: 88000.0

# %%
df["Cumulative_Sales"] = np.cumsum(df["Total_Sales"])
print(df[["OrderID","Cumulative_Sales"]])
# Out:
#    OrderID  Cumulative_Sales
# 0      101            100000
# 1      102            102500
# 2      103            107000
# 3      104            159000
# 4      105            161400
# 5      106            169800
# 6      107            271800
# 7      108            275650
# 8      109            283650
# 9      110            442650

# %%
plt.boxplot(df["Total_Sales"])
plt.title("Box Plot of Total Sales")
plt.ylabel("Total Sales")
plt.savefig("box plot for total sales")
plt.show()

# %%
# # compare the distribution of total regions of total sales using boxplot
# first line selects only those rows whose region is  NORTH (SAME WITH ALL)

# %%
north = df[df["Region"]=="North"]["Total_Sales"]
south = df[df["Region"]=="South"]["Total_Sales"]
east = df[df["Region"]=="East"]["Total_Sales"]
west = df[df["Region"]=="West"]["Total_Sales"]

plt.boxplot([north, south, east, west], labels=["North","South","East","West"])
plt.title("Region Wise Sales Distribution")
plt.ylabel("Total Sales")
plt.savefig("region wise sales distribution")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7368\2148235927.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([north, south, east, west], labels=["North","South","East","West"])

# %%
#this is the shorter version of pvs. one 
#Pandas automatically groups the data by "region" and creates boxplot

# %%
df.boxplot(column="Total_Sales", by="Region")
plt.title("Region Wise Boxplot")
plt.suptitle("")
plt.savefig("region wise boxplot")
plt.show()
